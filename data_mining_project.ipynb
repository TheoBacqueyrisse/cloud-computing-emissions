# %% [markdown]
# # **Cloud Computing Emissions Project**

# %%
import pandas as pd
import numpy as np
import requests
import os
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
username = "tidyverse"
name_repo = "tidyverse"
token = "git_token"

# %% [markdown]
# ## Collect the Worflow Runs from a chosen Repository

# %% [markdown]
# ### Let us define a function to get 100 runs from a repository

# %%
def get_workflows_from_repo(token, user_name, name_repo, page_nb):

  url = f'https://api.github.com/repos/{user_name}/{name_repo}/actions/runs?per_page=100&page={page_nb}'

  cmd = 'curl -G -H f"Authorization: token {token_git}" {url}'
  os.system(cmd.format(token_git = token, url = url))

  headers = {'Authorization': f'token {token}'}
  response = requests.get(url, headers=headers)

  if response.status_code == 200:
      workflows_data = response.json()
  else:
      print(f"Échec de la requête avec le code d'état {response.status_code}")

  return pd.DataFrame(workflows_data['workflow_runs'])

# %%
df = get_workflows_from_repo(token, username, name_repo, 1)
df
# Out:
#             id                        name                     node_id  \
# 0   7182346372               test-coverage  WFR_kwLOBAYhu88AAAABrBnohA
# 1   7182346369                 R-CMD-check  WFR_kwLOBAYhu88AAAABrBnogQ
# 2   7182346354                     pkgdown  WFR_kwLOBAYhu88AAAABrBnocg
# 3   7182346353                        lint  WFR_kwLOBAYhu88AAAABrBnocQ
# 4   7101667450                        lint  WFR_kwLOBAYhu88AAAABp0rYeg
# ..         ...                         ...                         ...
# 95  4256502504                 R-CMD-check        WFR_kwLOBAYhu879tRLo
# 96  4184701393  pages build and deployment        WFR_kwLOBAYhu875bXnR
# 97  4184669073                 R-CMD-check        WFR_kwLOBAYhu875bPuR
# 98  4184669062                     pkgdown        WFR_kwLOBAYhu875bPuG
# 99  4184669061               test-coverage        WFR_kwLOBAYhu875bPuF
#
#    head_branch                                  head_sha  \
# 0        lintr  8e0fde20fcb45ddfaaa56e45b95b7f2de096968e
# 1        lintr  8e0fde20fcb45ddfaaa56e45b95b7f2de096968e
# 2        lintr  8e0fde20fcb45ddfaaa56e45b95b7f2de096968e
# 3        lintr  8e0fde20fcb45ddfaaa56e45b95b7f2de096968e
# 4        lintr  443e932b2be27c9babbca68f1566c987587e9b50
# ..         ...                                       ...
# 95        main  ce4a7ba700c62bc306e601271076fcfea399c094
# 96    gh-pages  f387311da4b8dacbf7125ed1a4d2344123d8aa97
# 97        main  d4a33f6ebc89cf246a99922579f904c1e0fadaea
# 98        main  d4a33f6ebc89cf246a99922579f904c1e0fadaea
# 99        main  d4a33f6ebc89cf246a99922579f904c1e0fadaea
#
#                                     path  \
# 0   .github/workflows/test-coverage.yaml
# 1     .github/workflows/R-CMD-check.yaml
# 2         .github/workflows/pkgdown.yaml
# 3            .github/workflows/lint.yaml
# 4            .github/workflows/lint.yaml
# ..                                   ...
# 95    .github/workflows/R-CMD-check.yaml
# 96  dynamic/pages/pages-build-deployment
# 97    .github/workflows/R-CMD-check.yaml
# 98        .github/workflows/pkgdown.yaml
# 99  .github/workflows/test-coverage.yaml
#
#                             display_title  run_number         event  \
# 0   Use .lintr to enforce tidyverse style          82  pull_request
# 1   Use .lintr to enforce tidyverse style          82  pull_request
# 2   Use .lintr to enforce tidyverse style          71  pull_request
# 3   Use .lintr to enforce tidyverse style           2  pull_request
# 4   Use .lintr to enforce tidyverse style           1  pull_request
# ..                                    ...         ...           ...
# 95      Increment version number to 2.0.0          66          push
# 96             pages build and deployment          23       dynamic
# 97                          Check revdeps          65          push
# 98                          Check revdeps          52          push
# 99                          Check revdeps          65          push
#
#        status  ...                                           logs_url  \
# 0   completed  ...  https://api.github.com/repos/tidyverse/tidyver...
# 1   completed  ...  https://api.github.com/repos/tidyverse/tidyver...
# 2   completed  ...  https://api.github.com/repos/tidyverse/tidyver...
# 3   completed  ...  https://api.github.com/repos/tidyverse/tidyver...
# 4   completed  ...  https://api.github.com/repos/tidyverse/tidyver...
# ..        ...  ...                                                ...
# 95  completed  ...  https://api.github.com/repos/tidyverse/tidyver...
# 96  completed  ...  https://api.github.com/repos/tidyverse/tidyver...
# 97  completed  ...  https://api.github.com/repos/tidyverse/tidyver...
# 98  completed  ...  https://api.github.com/repos/tidyverse/tidyver...
# 99  completed  ...  https://api.github.com/repos/tidyverse/tidyver...
#
#                                       check_suite_url  \
# 0   https://api.github.com/repos/tidyverse/tidyver...
# 1   https://api.github.com/repos/tidyverse/tidyver...
# 2   https://api.github.com/repos/tidyverse/tidyver...
# 3   https://api.github.com/repos/tidyverse/tidyver...
# 4   https://api.github.com/repos/tidyverse/tidyver...
# ..                                                ...
# 95  https://api.github.com/repos/tidyverse/tidyver...
# 96  https://api.github.com/repos/tidyverse/tidyver...
# 97  https://api.github.com/repos/tidyverse/tidyver...
# 98  https://api.github.com/repos/tidyverse/tidyver...
# 99  https://api.github.com/repos/tidyverse/tidyver...
#
#                                         artifacts_url  \
# 0   https://api.github.com/repos/tidyverse/tidyver...
# 1   https://api.github.com/repos/tidyverse/tidyver...
# 2   https://api.github.com/repos/tidyverse/tidyver...
# 3   https://api.github.com/repos/tidyverse/tidyver...
# 4   https://api.github.com/repos/tidyverse/tidyver...
# ..                                                ...
# 95  https://api.github.com/repos/tidyverse/tidyver...
# 96  https://api.github.com/repos/tidyverse/tidyver...
# 97  https://api.github.com/repos/tidyverse/tidyver...
# 98  https://api.github.com/repos/tidyverse/tidyver...
# 99  https://api.github.com/repos/tidyverse/tidyver...
#
#                                            cancel_url  \
# 0   https://api.github.com/repos/tidyverse/tidyver...
# 1   https://api.github.com/repos/tidyverse/tidyver...
# 2   https://api.github.com/repos/tidyverse/tidyver...
# 3   https://api.github.com/repos/tidyverse/tidyver...
# 4   https://api.github.com/repos/tidyverse/tidyver...
# ..                                                ...
# 95  https://api.github.com/repos/tidyverse/tidyver...
# 96  https://api.github.com/repos/tidyverse/tidyver...
# 97  https://api.github.com/repos/tidyverse/tidyver...
# 98  https://api.github.com/repos/tidyverse/tidyver...
# 99  https://api.github.com/repos/tidyverse/tidyver...
#
#                                             rerun_url previous_attempt_url  \
# 0   https://api.github.com/repos/tidyverse/tidyver...                 None
# 1   https://api.github.com/repos/tidyverse/tidyver...                 None
# 2   https://api.github.com/repos/tidyverse/tidyver...                 None
# 3   https://api.github.com/repos/tidyverse/tidyver...                 None
# 4   https://api.github.com/repos/tidyverse/tidyver...                 None
# ..                                                ...                  ...
# 95  https://api.github.com/repos/tidyverse/tidyver...                 None
# 96  https://api.github.com/repos/tidyverse/tidyver...                 None
# 97  https://api.github.com/repos/tidyverse/tidyver...                 None
# 98  https://api.github.com/repos/tidyverse/tidyver...                 None
# 99  https://api.github.com/repos/tidyverse/tidyver...                 None
#
#                                          workflow_url  \
# 0   https://api.github.com/repos/tidyverse/tidyver...
# 1   https://api.github.com/repos/tidyverse/tidyver...
# 2   https://api.github.com/repos/tidyverse/tidyver...
# 3   https://api.github.com/repos/tidyverse/tidyver...
# 4   https://api.github.com/repos/tidyverse/tidyver...
# ..                                                ...
# 95  https://api.github.com/repos/tidyverse/tidyver...
# 96  https://api.github.com/repos/tidyverse/tidyver...
# 97  https://api.github.com/repos/tidyverse/tidyver...
# 98  https://api.github.com/repos/tidyverse/tidyver...
# 99  https://api.github.com/repos/tidyverse/tidyver...
#
#                                           head_commit  \
# 0   {'id': '8e0fde20fcb45ddfaaa56e45b95b7f2de09696...
# 1   {'id': '8e0fde20fcb45ddfaaa56e45b95b7f2de09696...
# 2   {'id': '8e0fde20fcb45ddfaaa56e45b95b7f2de09696...
# 3   {'id': '8e0fde20fcb45ddfaaa56e45b95b7f2de09696...
# 4   {'id': '443e932b2be27c9babbca68f1566c987587e9b...
# ..                                                ...
# 95  {'id': 'ce4a7ba700c62bc306e601271076fcfea399c0...
# 96  {'id': 'f387311da4b8dacbf7125ed1a4d2344123d8aa...
# 97  {'id': 'd4a33f6ebc89cf246a99922579f904c1e0fada...
# 98  {'id': 'd4a33f6ebc89cf246a99922579f904c1e0fada...
# 99  {'id': 'd4a33f6ebc89cf246a99922579f904c1e0fada...
#
#                                            repository  \
# 0   {'id': 67510715, 'node_id': 'MDEwOlJlcG9zaXRvc...
# 1   {'id': 67510715, 'node_id': 'MDEwOlJlcG9zaXRvc...
# 2   {'id': 67510715, 'node_id': 'MDEwOlJlcG9zaXRvc...
# 3   {'id': 67510715, 'node_id': 'MDEwOlJlcG9zaXRvc...
# 4   {'id': 67510715, 'node_id': 'MDEwOlJlcG9zaXRvc...
# ..                                                ...
# 95  {'id': 67510715, 'node_id': 'MDEwOlJlcG9zaXRvc...
# 96  {'id': 67510715, 'node_id': 'MDEwOlJlcG9zaXRvc...
# 97  {'id': 67510715, 'node_id': 'MDEwOlJlcG9zaXRvc...
# 98  {'id': 67510715, 'node_id': 'MDEwOlJlcG9zaXRvc...
# 99  {'id': 67510715, 'node_id': 'MDEwOlJlcG9zaXRvc...
#
#                                       head_repository
# 0   {'id': 727739570, 'node_id': 'R_kgDOK2Bssg', '...
# 1   {'id': 727739570, 'node_id': 'R_kgDOK2Bssg', '...
# 2   {'id': 727739570, 'node_id': 'R_kgDOK2Bssg', '...
# 3   {'id': 727739570, 'node_id': 'R_kgDOK2Bssg', '...
# 4   {'id': 727739570, 'node_id': 'R_kgDOK2Bssg', '...
# ..                                                ...
# 95  {'id': 67510715, 'node_id': 'MDEwOlJlcG9zaXRvc...
# 96  {'id': 67510715, 'node_id': 'MDEwOlJlcG9zaXRvc...
# 97  {'id': 67510715, 'node_id': 'MDEwOlJlcG9zaXRvc...
# 98  {'id': 67510715, 'node_id': 'MDEwOlJlcG9zaXRvc...
# 99  {'id': 67510715, 'node_id': 'MDEwOlJlcG9zaXRvc...
#
# [100 rows x 35 columns]

# %% [markdown]
# ### Let us define a function to get all workflow Runs from a repository

# %%
def get_all_workflows_from_repo(token, username, name_repo):

  df_final = pd.DataFrame()
  page_nb = 1
  while True:
    df = get_workflows_from_repo(token, username, name_repo, page_nb)

    if df.empty :
      break

    page_nb += 1
    df_final = pd.concat([df_final, df], axis = 0)

  return df_final

# %%
df = get_all_workflows_from_repo(token, username, name_repo)

# %%
# Save Data containing runs in Drive file
df.to_csv(f'/content/drive/MyDrive/Data Mining Data/{name_repo}_wo_co2', index = False)

# %% [markdown]
# ## Collect the jobs for the given Workflow Runs

# %% [markdown]
# ### Let us define a function taking Runs from a Repo as parameter and sending all the jobs for these runs

# %%
def get_jobs_from_runs(token, username, name_repo, df_runs):

  df_jobs = pd.DataFrame()

  for i in df_runs['id']:

    url = f'https://api.github.com/repos/{username}/{name_repo}/actions/runs/{i}/jobs'

    cmd = f'curl -L \
      -H "Accept: application/vnd.github+json" \
      -H f"Authorization: Bearer {token}" \
      -H "X-GitHub-Api-Version: 2022-11-28" \
      {url}'

    os.system(cmd)

    headers = {'Authorization': f'token {token}'}
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        run_id_jobs = response.json()
    else:
        print(f"Échec de la requête avec le code d'état {response.status_code}")
        continue

    df_jobs = pd.concat([df_jobs, pd.DataFrame(run_id_jobs['jobs'])], axis = 0)
  return df_jobs

# %%
pd.set_option('display.max_columns', 25)
df_jobs = get_jobs_from_runs(token, username, name_repo, df)
df_jobs.head()
# Out:
#             id      run_id  workflow_name head_branch  \
# 0  19558655750  7182346372  test-coverage       lintr
# 0  19558655753  7182346369    R-CMD-check       lintr
# 1  19558656399  7182346369    R-CMD-check       lintr
# 2  19558656825  7182346369    R-CMD-check       lintr
# 3  19558657128  7182346369    R-CMD-check       lintr
#
#                                              run_url  run_attempt  \
# 0  https://api.github.com/repos/tidyverse/tidyver...            1
# 0  https://api.github.com/repos/tidyverse/tidyver...            1
# 1  https://api.github.com/repos/tidyverse/tidyver...            1
# 2  https://api.github.com/repos/tidyverse/tidyver...            1
# 3  https://api.github.com/repos/tidyverse/tidyver...            1
#
#                      node_id                                  head_sha  \
# 0  CR_kwDOBAYhu88AAAAEjclnBg  8e0fde20fcb45ddfaaa56e45b95b7f2de096968e
# 0  CR_kwDOBAYhu88AAAAEjclnCQ  8e0fde20fcb45ddfaaa56e45b95b7f2de096968e
# 1  CR_kwDOBAYhu88AAAAEjclpjw  8e0fde20fcb45ddfaaa56e45b95b7f2de096968e
# 2  CR_kwDOBAYhu88AAAAEjclrOQ  8e0fde20fcb45ddfaaa56e45b95b7f2de096968e
# 3  CR_kwDOBAYhu88AAAAEjclsaA  8e0fde20fcb45ddfaaa56e45b95b7f2de096968e
#
#                                                  url  \
# 0  https://api.github.com/repos/tidyverse/tidyver...
# 0  https://api.github.com/repos/tidyverse/tidyver...
# 1  https://api.github.com/repos/tidyverse/tidyver...
# 2  https://api.github.com/repos/tidyverse/tidyver...
# 3  https://api.github.com/repos/tidyverse/tidyver...
#
#                                             html_url     status conclusion  \
# 0  https://github.com/tidyverse/tidyverse/actions...  completed    success
# 0  https://github.com/tidyverse/tidyverse/actions...  completed    success
# 1  https://github.com/tidyverse/tidyverse/actions...  completed    success
# 2  https://github.com/tidyverse/tidyverse/actions...  completed    success
# 3  https://github.com/tidyverse/tidyverse/actions...  completed    success
#
#              created_at            started_at          completed_at  \
# 0  2023-12-12T13:45:17Z  2023-12-12T13:45:24Z  2023-12-12T13:46:59Z
# 0  2023-12-12T13:45:17Z  2023-12-12T13:45:25Z  2023-12-12T13:48:37Z
# 1  2023-12-12T13:45:18Z  2023-12-12T13:45:27Z  2023-12-12T13:48:47Z
# 2  2023-12-12T13:45:19Z  2023-12-12T13:45:27Z  2023-12-12T13:49:55Z
# 3  2023-12-12T13:45:19Z  2023-12-12T13:45:27Z  2023-12-12T13:52:44Z
#
#                        name  \
# 0             test-coverage
# 0    macos-latest (release)
# 1  windows-latest (release)
# 2      windows-latest (3.6)
# 3      windows-latest (4.1)
#
#                                                steps  \
# 0  [{'name': 'Set up job', 'status': 'completed',...
# 0  [{'name': 'Set up job', 'status': 'completed',...
# 1  [{'name': 'Set up job', 'status': 'completed',...
# 2  [{'name': 'Set up job', 'status': 'completed',...
# 3  [{'name': 'Set up job', 'status': 'completed',...
#
#                                        check_run_url            labels  \
# 0  https://api.github.com/repos/tidyverse/tidyver...   [ubuntu-latest]
# 0  https://api.github.com/repos/tidyverse/tidyver...    [macos-latest]
# 1  https://api.github.com/repos/tidyverse/tidyver...  [windows-latest]
# 2  https://api.github.com/repos/tidyverse/tidyver...  [windows-latest]
# 3  https://api.github.com/repos/tidyverse/tidyver...  [windows-latest]
#
#   runner_id        runner_name runner_group_id runner_group_name
# 0        13  GitHub Actions 13               2    GitHub Actions
# 0         3   GitHub Actions 3               2    GitHub Actions
# 1        10  GitHub Actions 10               2    GitHub Actions
# 2         9   GitHub Actions 9               2    GitHub Actions
# 3        11  GitHub Actions 11               2    GitHub Actions

# %%
df_jobs['started_at'] = pd.to_datetime(df_jobs['started_at'])
df_jobs['completed_at'] = pd.to_datetime(df_jobs['completed_at'])
df_jobs['duration'] = df_jobs['completed_at'] - df_jobs['started_at']
df_jobs['duration'] = pd.to_timedelta(df_jobs['duration'])/ pd.Timedelta(hours=1)

# %%
# Save Data with Jobs to Drive file
df_jobs.to_csv('/content/drive/MyDrive/Data Mining Data/numpy_with_logs', index = False)

# %% [markdown]
# ## Let us Create a function that computes Carbon Emissions from each Job using the Climatiq API.

# %%
df = df_jobs

# %%
df.columns
# Out:
# Index(['id', 'run_id', 'workflow_name', 'head_branch', 'run_url',
#        'run_attempt', 'node_id', 'head_sha', 'url', 'html_url', 'status',
#        'conclusion', 'created_at', 'started_at', 'completed_at', 'name',
#        'steps', 'check_run_url', 'labels', 'runner_id', 'runner_name',
#        'runner_group_id', 'runner_group_name', 'duration'],
#       dtype='object')

# %%
apikey_climatiq = 'apikey_climatiq	'

# %%
def get_co2_emissions_from_jobs(df):
  climatiq_url = 'https://beta4.api.climatiq.io/compute/azure/cpu'
  co2_ems = []

  for i in range(len(df)):
    dur = df.iloc[i]['duration']

    data = {
    "cpu_count": 1,
    "region": "west_us",
    "duration": dur,
    "duration_unit": "h",
    }

    data = json.dumps(data)

    header = {
        'Authorization': f'Bearer {apikey_climatiq}',
    }

    response = requests.post(climatiq_url, headers=header, data=data)

    if response.status_code == 200:
        api_response = response.json()
    else:
        print(f"Failed to fetch data. Status code: {response.status_code}")
        print(response.text)
    co2_ems.append(api_response['co2e'])

  df['co2_emission'] = co2_ems
  df['unit'] = 'kg'

  return df

# %%
df = get_co2_emissions_from_jobs(df)

# %%
df
# Out:
#              id      run_id  workflow_name head_branch  \
# 0   19558655750  7182346372  test-coverage       lintr
# 0   19558655753  7182346369    R-CMD-check       lintr
# 1   19558656399  7182346369    R-CMD-check       lintr
# 2   19558656825  7182346369    R-CMD-check       lintr
# 3   19558657128  7182346369    R-CMD-check       lintr
# ..          ...         ...            ...         ...
# 1    9743297000  3564477841       Commands        main
# 0    9743290561  3564475573       Commands        main
# 1    9743290824  3564475573       Commands        main
# 0    9697704268  3544178197       Commands        main
# 1    9697704364  3544178197       Commands        main
#
#                                               run_url  run_attempt  \
# 0   https://api.github.com/repos/tidyverse/tidyver...            1
# 0   https://api.github.com/repos/tidyverse/tidyver...            1
# 1   https://api.github.com/repos/tidyverse/tidyver...            1
# 2   https://api.github.com/repos/tidyverse/tidyver...            1
# 3   https://api.github.com/repos/tidyverse/tidyver...            1
# ..                                                ...          ...
# 1   https://api.github.com/repos/tidyverse/tidyver...            1
# 0   https://api.github.com/repos/tidyverse/tidyver...            1
# 1   https://api.github.com/repos/tidyverse/tidyver...            1
# 0   https://api.github.com/repos/tidyverse/tidyver...            1
# 1   https://api.github.com/repos/tidyverse/tidyver...            1
#
#                       node_id                                  head_sha  \
# 0   CR_kwDOBAYhu88AAAAEjclnBg  8e0fde20fcb45ddfaaa56e45b95b7f2de096968e
# 0   CR_kwDOBAYhu88AAAAEjclnCQ  8e0fde20fcb45ddfaaa56e45b95b7f2de096968e
# 1   CR_kwDOBAYhu88AAAAEjclpjw  8e0fde20fcb45ddfaaa56e45b95b7f2de096968e
# 2   CR_kwDOBAYhu88AAAAEjclrOQ  8e0fde20fcb45ddfaaa56e45b95b7f2de096968e
# 3   CR_kwDOBAYhu88AAAAEjclsaA  8e0fde20fcb45ddfaaa56e45b95b7f2de096968e
# ..                        ...                                       ...
# 1   CR_kwDOBAYhu88AAAACRL7p6A  aeabcde8c6ae435f16b5173682d5667d292829fb
# 0   CR_kwDOBAYhu88AAAACRL7QwQ  aeabcde8c6ae435f16b5173682d5667d292829fb
# 1   CR_kwDOBAYhu88AAAACRL7RyA  aeabcde8c6ae435f16b5173682d5667d292829fb
# 0   CR_kwDOBAYhu88AAAACQgc5TA  aeabcde8c6ae435f16b5173682d5667d292829fb
# 1   CR_kwDOBAYhu88AAAACQgc5rA  aeabcde8c6ae435f16b5173682d5667d292829fb
#
#                                                   url  \
# 0   https://api.github.com/repos/tidyverse/tidyver...
# 0   https://api.github.com/repos/tidyverse/tidyver...
# 1   https://api.github.com/repos/tidyverse/tidyver...
# 2   https://api.github.com/repos/tidyverse/tidyver...
# 3   https://api.github.com/repos/tidyverse/tidyver...
# ..                                                ...
# 1   https://api.github.com/repos/tidyverse/tidyver...
# 0   https://api.github.com/repos/tidyverse/tidyver...
# 1   https://api.github.com/repos/tidyverse/tidyver...
# 0   https://api.github.com/repos/tidyverse/tidyver...
# 1   https://api.github.com/repos/tidyverse/tidyver...
#
#                                              html_url     status conclusion  \
# 0   https://github.com/tidyverse/tidyverse/actions...  completed    success
# 0   https://github.com/tidyverse/tidyverse/actions...  completed    success
# 1   https://github.com/tidyverse/tidyverse/actions...  completed    success
# 2   https://github.com/tidyverse/tidyverse/actions...  completed    success
# 3   https://github.com/tidyverse/tidyverse/actions...  completed    success
# ..                                                ...        ...        ...
# 1   https://github.com/tidyverse/tidyverse/actions...  completed    skipped
# 0   https://github.com/tidyverse/tidyverse/actions...  completed    skipped
# 1   https://github.com/tidyverse/tidyverse/actions...  completed    skipped
# 0   https://github.com/tidyverse/tidyverse/actions...  completed    skipped
# 1   https://github.com/tidyverse/tidyverse/actions...  completed    skipped
#
#     ...              completed_at                      name  \
# 0   ... 2023-12-12 13:46:59+00:00             test-coverage
# 0   ... 2023-12-12 13:48:37+00:00    macos-latest (release)
# 1   ... 2023-12-12 13:48:47+00:00  windows-latest (release)
# 2   ... 2023-12-12 13:49:55+00:00      windows-latest (3.6)
# 3   ... 2023-12-12 13:52:44+00:00      windows-latest (4.1)
# ..  ...                       ...                       ...
# 1   ... 2022-11-28 11:51:59+00:00                  document
# 0   ... 2022-11-28 11:51:37+00:00                     style
# 1   ... 2022-11-28 11:51:38+00:00                  document
# 0   ... 2022-11-24 23:23:49+00:00                     style
# 1   ... 2022-11-24 23:23:50+00:00                  document
#
#                                                 steps  \
# 0   [{'name': 'Set up job', 'status': 'completed',...
# 0   [{'name': 'Set up job', 'status': 'completed',...
# 1   [{'name': 'Set up job', 'status': 'completed',...
# 2   [{'name': 'Set up job', 'status': 'completed',...
# 3   [{'name': 'Set up job', 'status': 'completed',...
# ..                                                ...
# 1                                                  []
# 0                                                  []
# 1                                                  []
# 0                                                  []
# 1                                                  []
#
#                                         check_run_url            labels  \
# 0   https://api.github.com/repos/tidyverse/tidyver...   [ubuntu-latest]
# 0   https://api.github.com/repos/tidyverse/tidyver...    [macos-latest]
# 1   https://api.github.com/repos/tidyverse/tidyver...  [windows-latest]
# 2   https://api.github.com/repos/tidyverse/tidyver...  [windows-latest]
# 3   https://api.github.com/repos/tidyverse/tidyver...  [windows-latest]
# ..                                                ...               ...
# 1   https://api.github.com/repos/tidyverse/tidyver...                []
# 0   https://api.github.com/repos/tidyverse/tidyver...                []
# 1   https://api.github.com/repos/tidyverse/tidyver...                []
# 0   https://api.github.com/repos/tidyverse/tidyver...                []
# 1   https://api.github.com/repos/tidyverse/tidyver...                []
#
#    runner_id        runner_name runner_group_id runner_group_name  duration  \
# 0         13  GitHub Actions 13               2    GitHub Actions  0.026389
# 0          3   GitHub Actions 3               2    GitHub Actions  0.053333
# 1         10  GitHub Actions 10               2    GitHub Actions  0.055556
# 2          9   GitHub Actions 9               2    GitHub Actions  0.074444
# 3         11  GitHub Actions 11               2    GitHub Actions  0.121389
# ..       ...                ...             ...               ...       ...
# 1       None               None            None              None  0.000000
# 0       None               None            None              None  0.000000
# 1       None               None            None              None  0.000000
# 0       None               None            None              None  0.000000
# 1       None               None            None              None  0.000000
#
#    co2_emission  unit
# 0      0.000017    kg
# 0      0.000035    kg
# 1      0.000036    kg
# 2      0.000048    kg
# 3      0.000079    kg
# ..          ...   ...
# 1      0.000000    kg
# 0      0.000000    kg
# 1      0.000000    kg
# 0      0.000000    kg
# 1      0.000000    kg
#
# [340 rows x 26 columns]

# %%
# Save final data to Drive file
df.to_csv(f'/content/drive/MyDrive/Data Mining Data/pandas_data_with_co2.csv')
